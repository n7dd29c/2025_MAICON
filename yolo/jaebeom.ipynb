# %%
from ultralytics import YOLO
import torch

print("PyTorch 버전:", torch.__version__)
print("CUDA 사용 가능?:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("CUDA 버전:", torch.version.cuda)
    print("GPU 이름:", torch.cuda.get_device_name(0))
else:
    print("현재는 CPU 모드로 동작 중입니다.")
# Out:
# PyTorch 버전: 2.5.1
# CUDA 사용 가능?: True
# CUDA 버전: 12.1
# GPU 이름: NVIDIA GeForce RTX 4060

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Admin\zzae1

# %%
DATASET_PATH = "C:/Users/Admin/zzae1/Object7.v7-maicon_mortar_background.yolov8" # 본인 경로에 맞게 수정
print("경로 지정 완료: ", DATASET_PATH)
# Out:
# 경로 지정 완료:  C:/Users/Admin/zzae1/Object7.v7-maicon_mortar_background.yolov8

# %%
import glob, os

save_dir = "C:/Users/Admin/zzae1/Object7.v7-maicon_mortar_background.yolov8"

yaml_candidates = glob.glob(os.path.join(DATASET_PATH, "**", "data.yaml"), recursive=True)
assert len(yaml_candidates) > 0, "data.yaml을 찾지 못했습니다. 다운로드 경로를 확인하세요."
DATA_YAML = yaml_candidates[0]
print("사용할 data.yaml:", DATA_YAML)

model = YOLO("yolov8n.pt")
results = model.train(
    data=DATA_YAML,
    epochs=30,
    imgsz=640,
    batch=16,
    project=save_dir,
    name="yolov8n",
)
# Out:
# 사용할 data.yaml: C:/Users/Admin/zzae1/Object7.v7-maicon_mortar_background.yolov8\data.yaml
# Ultralytics 8.3.229  Python-3.11.3 torch-2.5.1 CUDA:0 (NVIDIA GeForce RTX 4060, 8188MiB)
# ...

# %%
### 추론 테스트 ###
from ultralytics import YOLO
import os, glob
best_ckpt = "C:/Users/Admin/zzae1/Object7.v7-maicon_mortar_background.yolov8/yolov8n/weights/best.pt"
ckpt = best_ckpt if os.path.exists(best_ckpt) else last_ckpt
print("사용 가중치:", ckpt)

if os.path.exists(ckpt):
    model = YOLO(ckpt)
    test_imgs = glob.glob(os.path.join("C:/Users/Admin/zzae1/Object7.v7-maicon_mortar_background.yolov8", "**", "valid", "images", "*.jpg"), recursive=True)[:59]
    if test_imgs:
        preds = model.predict(test_imgs, save=True)
        print("추론 완료. 결과 폴더를 확인하세요.")
    else:
        print("테스트 이미지가 없습니다. 추론 스킵.")
else:
    print("체크포인트를 찾지 못했습니다.")
# Out:
# 사용 가중치: C:/Users/Admin/zzae1/Object7.v7-maicon_mortar_background.yolov8/yolov8n/weights/best.pt
#
# 0: 640x640 1 Car, 6.3ms
# 1: 640x640 1 Car, 6.3ms
# 2: 640x640 1 Car, 1 Missile, 6.3ms
# 3: 640x640 1 Car, 1 Missile, 6.3ms
# 4: 640x640 1 Missile, 6.3ms
# 5: 640x640 2 Mortars, 6.3ms
# 6: 640x640 (no detections), 6.3ms
# 7: 640x640 1 Hazmat, 1 Tank, 6.3ms
# 8: 640x640 1 Enemy, 1 Hazmat, 1 Missile, 6.3ms
# 9: 640x640 1 Car, 1 Hazmat, 6.3ms
# 10: 640x640 1 Car, 1 Hazmat, 6.3ms
# 11: 640x640 1 Hazmat, 1 Tank, 6.3ms
# 12: 640x640 1 Tank, 6.3ms
# 13: 640x640 1 Enemy, 1 Hazmat, 6.3ms
# 14: 640x640 1 Car, 1 Hazmat, 1 Missile, 6.3ms
# 15: 640x640 1 Car, 1 Mortar, 6.3ms
# 16: 640x640 1 Car, 1 Missile, 1 Mortar, 6.3ms
# 17: 640x640 1 Enemy, 1 Hazmat, 1 Mortar, 6.3ms
# 18: 640x640 1 Enemy, 1 Hazmat, 1 Missile, 6.3ms
# 19: 640x640 1 Car, 1 Enemy, 2 Hazmats, 1 Missile, 6.3ms
# 20: 640x640 1 Enemy, 1 Missile, 6.3ms
# 21: 640x640 (no detections), 6.3ms
# ...

# %%
# Out:
#   Cell In[24], line 1
#     python train.py --data your_data.yaml --epochs 50 --batch-size 16 --img-size 640 --lr_find
#            ^
# SyntaxError: invalid syntax
